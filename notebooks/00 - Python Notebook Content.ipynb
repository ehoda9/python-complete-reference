# %% [markdown]
# # 00 - Python Notebook Content
# فهرس سريع لمكان كل موضوع جوه مجلد **Offline Notebook - Mastering Python Summary**، بدون تفاصيل كتير - الهدف إني اعرف تلاقي أي حاجة بسرعة.
#
# انتقال سريع: [01](#p01) · [02](#p02) · [03](#p03) · [04](#p04) · [05](#p05) · [06](#p06) · [07](#p07) · [08](#p08) · [09](#p09) · [10](#p10) · [11](#p11) · [12](#p12)

# %% [markdown]
# <a id="p01"></a>
#
# ## 01 - Python Fundamentals
# - [`01 - Comments.ipynb`](01%20-%20Python%20Fundamentals/01%20-%20Comments.ipynb) → التعليقات
# - [`02 - Data Types.ipynb`](01%20-%20Python%20Fundamentals/02%20-%20Data%20Types.ipynb) → أنواع البيانات + كل حاجة عن الـ Strings (Escape Sequences, Concatenation, Indexing, Slicing, Methods)
# - [`03 - Variables.ipynb`](01%20-%20Python%20Fundamentals/03%20-%20Variables.ipynb) → المتغيرات و الـ Reserved Words
# - [`04 - Type Conversion.ipynb`](01%20-%20Python%20Fundamentals/04%20-%20Type%20Conversion.ipynb) → تحويل الأنواع
# - [`05 - User Input.ipynb`](01%20-%20Python%20Fundamentals/05%20-%20User%20Input.ipynb) → إدخال المستخدم (input)
# - [`06 - Operators.ipynb`](01%20-%20Python%20Fundamentals/06%20-%20Operators.ipynb) → كل الـ Operators (Arithmetic, Assignment, Comparison, Membership...)
# - [`07 - Keywords.ipynb`](01%20-%20Python%20Fundamentals/07%20-%20Keywords.ipynb) → مرجع سريع لكل الـ Keywords في بايثون

# %% [markdown]
# <a id="p02"></a>
#
# ## 02 - Python Collections
# - [`01 - Lists.ipynb`](02%20-%20Python%20Collections/01%20-%20Lists.ipynb) → القوائم
# - [`02 - Tuples.ipynb`](02%20-%20Python%20Collections/02%20-%20Tuples.ipynb) → الـ Tuples
# - [`03 - Sets & Frozen Sets.ipynb`](02%20-%20Python%20Collections/03%20-%20Sets%20&%20Frozen%20Sets.ipynb) → الـ Sets و الـ Frozen Sets
# - [`04 - Dictionaries.ipynb`](02%20-%20Python%20Collections/04%20-%20Dictionaries.ipynb) → القواميس
# - [`05 - Boolean & Containers Comparison.ipynb`](02%20-%20Python%20Collections/05%20-%20Boolean%20&%20Containers%20Comparison.ipynb) → القيم المنطقية + مقارنة سريعة بين كل الـ Containers

# %% [markdown]
# <a id="p03"></a>
#
# ## 03 - Built-ins & Modules
# - [`01 - Built-in Functions.ipynb`](03%20-%20Built-ins%20&%20Modules/01%20-%20Built-in%20Functions.ipynb) → كل الدوال المدمجة مقسمة لفئات (General, Conversion, Math, Iteration, Objects, Strings, Files, OOP, Async)
# - [`02 - Built-in Modules.ipynb`](03%20-%20Built-ins%20&%20Modules/02%20-%20Built-in%20Modules.ipynb) → import و المكتبات المدمجة (math, random, os...)
# - [`03 - External Packages.ipynb`](03%20-%20Built-ins%20&%20Modules/03%20-%20External%20Packages.ipynb) → pip و المكتبات الخارجية

# %% [markdown]
# <a id="p04"></a>
#
# ## 04 - Control Flow
# - [`01 - If Elif Else.ipynb`](04%20-%20Control%20Flow/01%20-%20If%20Elif%20Else.ipynb) → الشروط
# - [`02 - While Loop.ipynb`](04%20-%20Control%20Flow/02%20-%20While%20Loop.ipynb) → حلقة While
# - [`03 - For Loop.ipynb`](04%20-%20Control%20Flow/03%20-%20For%20Loop.ipynb) → حلقة For
# - [`04 - Iterable vs Iterator.ipynb`](04%20-%20Control%20Flow/04%20-%20Iterable%20vs%20Iterator.ipynb) → الفرق بين Iterable و Iterator
# - [`05 - Generators.ipynb`](04%20-%20Control%20Flow/05%20-%20Generators.ipynb) → الـ Generators

# %% [markdown]
# <a id="p05"></a>
#
# ## 05 - Functions
# - [`01 - Functions Basics.ipynb`](05%20-%20Functions/01%20-%20Functions%20Basics.ipynb) → أساسيات الدوال
# - [`02 - Parameters & Arguments.ipynb`](05%20-%20Functions/02%20-%20Parameters%20&%20Arguments.ipynb) → المعاملات و الوسائط
# - [`03 - Default Parameters.ipynb`](05%20-%20Functions/03%20-%20Default%20Parameters.ipynb) → القيم الافتراضية
# - [`04 - Args Kwargs & Unpacking.ipynb`](05%20-%20Functions/04%20-%20Args%20Kwargs%20&%20Unpacking.ipynb) → `*args`, `**kwargs` و الـ Unpacking
# - [`05 - Function Scope.ipynb`](05%20-%20Functions/05%20-%20Function%20Scope.ipynb) → نطاق المتغيرات داخل الدوال
# - [`06 - Return Statement.ipynb`](05%20-%20Functions/06%20-%20Return%20Statement.ipynb) → جملة return
# - [`07 - Recursion.ipynb`](05%20-%20Functions/07%20-%20Recursion.ipynb) → العودية (Recursion)
# - [`08 - Lambda Functions.ipynb`](05%20-%20Functions/08%20-%20Lambda%20Functions.ipynb) → دوال Lambda
# - [`09 - Decorators.ipynb`](05%20-%20Functions/09%20-%20Decorators.ipynb) → الـ Decorators
# - [`10 - Docstrings.ipynb`](05%20-%20Functions/10%20-%20Docstrings.ipynb) → التوثيق (Docstrings)

# %% [markdown]
# <a id="p06"></a>
#
# ## 06 - File Handling
# - [`01 - File Handling.ipynb`](06%20-%20File%20Handling/01%20-%20File%20Handling.ipynb) → فتح وقراءة وكتابة الملفات
# - [`02 - Additional File Methods.ipynb`](06%20-%20File%20Handling/02%20-%20Additional%20File%20Methods.ipynb) → دوال وخصائص إضافية (seek, tell, mode...)

# %% [markdown]
# <a id="p07"></a>
#
# ## 07 - Errors & Exceptions
# - [`01 - Errors & Exceptions.ipynb`](07%20-%20Errors%20&%20Exceptions/01%20-%20Errors%20&%20Exceptions.ipynb) → الأخطاء والاستثناءات و raise
# - [`02 - Exception Handling.ipynb`](07%20-%20Errors%20&%20Exceptions/02%20-%20Exception%20Handling.ipynb) → try / except / else / finally

# %% [markdown]
# <a id="p08"></a>
#
# ## 08 - Regular Expressions
# - [`01 - Regular Expressions Foundations.ipynb`](08%20-%20Regular%20Expressions/01%20-%20Regular%20Expressions%20Foundations.ipynb) → أساسيات الـ Regex و module الـ `re`
# - [`02 - Regex Syntax, Character Classes & Quantifiers.ipynb`](08%20-%20Regular%20Expressions/02%20-%20Regex%20Syntax,%20Character%20Classes%20&%20Quantifiers.ipynb) → الـ Character Classes و الـ Quantifiers و الـ Anchors
# - [`03 - Regex Groups, Alternation & Assertions.ipynb`](08%20-%20Regular%20Expressions/03%20-%20Regex%20Groups,%20Alternation%20&%20Assertions.ipynb) → الـ Groups و الـ Alternation و الـ Lookahead / Lookbehind
# - [`04 - Regex Functions, Match Objects & Replacement.ipynb`](08%20-%20Regular%20Expressions/04%20-%20Regex%20Functions,%20Match%20Objects%20&%20Replacement.ipynb) → دوال `re` (search, match, findall, sub, split) و الـ Match Objects
# - [`05 - Regex Flags, Performance & Best Practices.ipynb`](08%20-%20Regular%20Expressions/05%20-%20Regex%20Flags,%20Performance%20&%20Best%20Practices.ipynb) → الـ Flags و الأداء و أفضل الممارسات

# %% [markdown]
# <a id="p09"></a>
#
# ## 09 - Object Oriented Programming
# - [`01 - OOP Foundations.ipynb`](09%20-%20Object%20Oriented%20Programming/01%20-%20OOP%20Foundations.ipynb) → أساسيات البرمجة الكائنية (OOP)
# - [`02 - Classes, Instances & __init__.ipynb`](09%20-%20Object%20Oriented%20Programming/02%20-%20Classes,%20Instances%20&%20__init__.ipynb) → الـ Classes و الـ Instances و `__init__`
# - [`03 - Attributes & Methods.ipynb`](09%20-%20Object%20Oriented%20Programming/03%20-%20Attributes%20&%20Methods.ipynb) → الـ Attributes و الـ Methods
# - [`04 - Encapsulation & Properties.ipynb`](09%20-%20Object%20Oriented%20Programming/04%20-%20Encapsulation%20&%20Properties.ipynb) → الـ Encapsulation و الـ `@property`
# - [`05 - Class & Static Methods.ipynb`](09%20-%20Object%20Oriented%20Programming/05%20-%20Class%20&%20Static%20Methods.ipynb) → `@classmethod` و `@staticmethod` و الـ Alternative Constructors
# - [`06 - Inheritance & super.ipynb`](09%20-%20Object%20Oriented%20Programming/06%20-%20Inheritance%20&%20super.ipynb) → الوراثة (Inheritance) و `super()`
# - [`07 - Multiple Inheritance, MRO & Mixins.ipynb`](09%20-%20Object%20Oriented%20Programming/07%20-%20Multiple%20Inheritance,%20MRO%20&%20Mixins.ipynb) → الوراثة المتعددة و الـ MRO و الـ Mixins
# - [`08 - Polymorphism, Duck Typing & Composition.ipynb`](09%20-%20Object%20Oriented%20Programming/08%20-%20Polymorphism,%20Duck%20Typing%20&%20Composition.ipynb) → الـ Polymorphism و الـ Duck Typing و الـ Composition
# - [`09 - Abstract Base Classes.ipynb`](09%20-%20Object%20Oriented%20Programming/09%20-%20Abstract%20Base%20Classes.ipynb) → الـ Abstract Base Classes (ABCs)
# - [`10 - Dunder Methods & Operator Overloading.ipynb`](09%20-%20Object%20Oriented%20Programming/10%20-%20Dunder%20Methods%20&%20Operator%20Overloading.ipynb) → الـ Dunder Methods و الـ Operator Overloading
# - [`11 - Object Model, Descriptors & __slots__.ipynb`](09%20-%20Object%20Oriented%20Programming/11%20-%20Object%20Model,%20Descriptors%20&%20__slots__.ipynb) → الـ Object Model و الـ Descriptors و `__slots__`
# - [`12 - Dataclasses & Enums.ipynb`](09%20-%20Object%20Oriented%20Programming/12%20-%20Dataclasses%20&%20Enums.ipynb) → الـ Dataclasses و الـ Enums
# - [`13 - OOP Design, Advanced Patterns & Best Practices.ipynb`](09%20-%20Object%20Oriented%20Programming/13%20-%20OOP%20Design,%20Advanced%20Patterns%20&%20Best%20Practices.ipynb) → تصميم الـ OOP و الـ Patterns المتقدمة و أفضل الممارسات

# %% [markdown]
# <a id="p10"></a>
#
# ## 10 - Type Hinting
# - [`01 - Type Hints Foundations.ipynb`](10%20-%20Type%20Hinting/01%20-%20Type%20Hints%20Foundations.ipynb) → أساسيات الـ Type Hints
# - [`02 - Collections, Union Types & Type Aliases.ipynb`](10%20-%20Type%20Hinting/02%20-%20Collections,%20Union%20Types%20&%20Type%20Aliases.ipynb) → الـ Collections و الـ Union Types و الـ Type Aliases
# - [`03 - TypeVar, Generic, Literal, Final & ClassVar.ipynb`](10%20-%20Type%20Hinting/03%20-%20TypeVar,%20Generic,%20Literal,%20Final%20&%20ClassVar.ipynb) → `TypeVar` و `Generic` و `Literal` و `Final` و `ClassVar`
# - [`04 - Protocols, TypedDict, NamedTuple & Callable.ipynb`](10%20-%20Type%20Hinting/04%20-%20Protocols,%20TypedDict,%20NamedTuple%20&%20Callable.ipynb) → `Protocol` و `TypedDict` و `NamedTuple` و `Callable`
# - [`05 - Advanced Type Hints_ Self, TypeGuard, overload, ParamSpec & Annotated.ipynb`](10%20-%20Type%20Hinting/05%20-%20Advanced%20Type%20Hints_%20Self,%20TypeGuard,%20overload,%20ParamSpec%20&%20Annotated.ipynb) → أنواع متقدمة: `Self` و `TypeGuard` و `overload` و `ParamSpec` و `Annotated`
# - [`06 - Typing Tools, Runtime Introspection & Python 3.14 Notes.ipynb`](10%20-%20Type%20Hinting/06%20-%20Typing%20Tools,%20Runtime%20Introspection%20&%20Python%203.14%20Notes.ipynb) → أدوات الـ Typing و الـ Runtime Introspection و ملاحظات Python 3.14

# %% [markdown]
# <a id="p11"></a>
#
# ## 11 - Comprehensions
# - [`01 - Comprehensions Foundations.ipynb`](11%20-%20Comprehensions/01%20-%20Comprehensions%20Foundations.ipynb) → أساسيات الـ Comprehensions (الشكل العام و الأنواع الأربعة)
# - [`02 - Conditions, Multiple Loops & Nested Comprehensions.ipynb`](11%20-%20Comprehensions/02%20-%20Conditions,%20Multiple%20Loops%20&%20Nested%20Comprehensions.ipynb) → الشروط و الـ `for` المتعددة و الـ Nested Comprehensions
# - [`03 - Dict, Set & Generator Expressions.ipynb`](11%20-%20Comprehensions/03%20-%20Dict,%20Set%20&%20Generator%20Expressions.ipynb) → الـ Dict و الـ Set Comprehensions و الـ Generator Expressions
# - [`04 - Scope, Walrus Operator & Async Comprehensions.ipynb`](11%20-%20Comprehensions/04%20-%20Scope,%20Walrus%20Operator%20&%20Async%20Comprehensions.ipynb) → الـ Scope و الـ Walrus Operator و الـ Async Comprehensions
# - [`05 - Performance, Readability & Best Practices.ipynb`](11%20-%20Comprehensions/05%20-%20Performance,%20Readability%20&%20Best%20Practices.ipynb) → الأداء و وضوح الكود و أفضل الممارسات

# %% [markdown]
# <a id="p12"></a>
#
# ## 12 - Itertools
# - [`01 - Itertools Foundations.ipynb`](12%20-%20Itertools/01%20-%20Itertools%20Foundations.ipynb) → أساسيات `itertools` و طريقة التفكير بالـ Pipelines
# - [`02 - Infinite Iterators.ipynb`](12%20-%20Itertools/02%20-%20Infinite%20Iterators.ipynb) → الـ Infinite Iterators: `count` و `cycle` و `repeat`
# - [`03 - Filtering & Slicing Iterators.ipynb`](12%20-%20Itertools/03%20-%20Filtering%20&%20Slicing%20Iterators.ipynb) → `islice` و `takewhile` و `dropwhile` و `filterfalse` و `compress`
# - [`04 - Chaining, Zipping & Mapping.ipynb`](12%20-%20Itertools/04%20-%20Chaining,%20Zipping%20&%20Mapping.ipynb) → `chain` و `zip_longest` و `starmap`
# - [`05 - Accumulate, Pairwise, Batched & Tee.ipynb`](12%20-%20Itertools/05%20-%20Accumulate,%20Pairwise,%20Batched%20&%20Tee.ipynb) → `accumulate` و `pairwise` و `batched` و `tee`
# - [`06 - Grouping with groupby.ipynb`](12%20-%20Itertools/06%20-%20Grouping%20with%20groupby.ipynb) → `groupby` و تجميع البيانات
# - [`07 - Combinatoric Iterators.ipynb`](12%20-%20Itertools/07%20-%20Combinatoric%20Iterators.ipynb) → `product` و `permutations` و `combinations`
# - [`08 - Recipes, Patterns & Best Practices.ipynb`](12%20-%20Itertools/08%20-%20Recipes,%20Patterns%20&%20Best%20Practices.ipynb) → الـ Recipes و الأنماط العملية و أفضل الممارسات
