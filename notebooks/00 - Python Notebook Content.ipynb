# %% [markdown]
# # 00 - Python Notebook Content
# A quick index of every notebook in the **notebooks** folder, in learning order. Each part builds on the ones before it.
#
# Jump to: [01](#p01) · [02](#p02) · [03](#p03) · [04](#p04) · [05](#p05) · [06](#p06) · [07](#p07) · [08](#p08) · [09](#p09) · [10](#p10) · [11](#p11) · [12](#p12) · [13](#p13) · [14](#p14)

# %% [markdown]
# <a id="p01"></a>
#
# ## 01 - Python Basics
# - [`01 - Comments.ipynb`](01%20-%20Python%20Basics/01%20-%20Comments.ipynb) - Single-line and inline comments, and how to comment out code
# - [`02 - Variables.ipynb`](01%20-%20Python%20Basics/02%20-%20Variables.ipynb) - Names that refer to values, and the naming rules
# - [`03 - Data Types.ipynb`](01%20-%20Python%20Basics/03%20-%20Data%20Types.ipynb) - Built-in types, escape sequences, concatenation, indexing, slicing and string methods
# - [`04 - Operators.ipynb`](01%20-%20Python%20Basics/04%20-%20Operators.ipynb) - Arithmetic, assignment, comparison (including chained) and membership operators
# - [`05 - Type Conversion.ipynb`](01%20-%20Python%20Basics/05%20-%20Type%20Conversion.ipynb) - Converting between `int`, `float`, `str`, `bool` and other types
# - [`06 - User Input.ipynb`](01%20-%20Python%20Basics/06%20-%20User%20Input.ipynb) - Reading text with `input()` and converting it
# - [`07 - String Formatting.ipynb`](01%20-%20Python%20Basics/07%20-%20String%20Formatting.ipynb) - f-strings, format specifications, `str.format()` and `%` formatting
# - [`08 - Built-in Modules.ipynb`](01%20-%20Python%20Basics/08%20-%20Built-in%20Modules.ipynb) - `import`, aliases, `from ... import`, custom modules and the module search path

# %% [markdown]
# <a id="p02"></a>
#
# ## 02 - Control Flow
# - [`01 - If Elif Else.ipynb`](02%20-%20Control%20Flow/01%20-%20If%20Elif%20Else.ipynb) - Conditions, nested `if` and the ternary operator
# - [`02 - While Loop.ipynb`](02%20-%20Control%20Flow/02%20-%20While%20Loop.ipynb) - `while`, `break`, `continue` and loop `else`
# - [`03 - For Loop.ipynb`](02%20-%20Control%20Flow/03%20-%20For%20Loop.ipynb) - `for`, iterables, `range()`, `break`, `continue` and loop `else`
# - [`04 - Match Case.ipynb`](02%20-%20Control%20Flow/04%20-%20Match%20Case.ipynb) - Structural pattern matching with `match` / `case`

# %% [markdown]
# <a id="p03"></a>
#
# ## 03 - Data Structures
# - [`01 - Lists.ipynb`](03%20-%20Data%20Structures/01%20-%20Lists.ipynb) - Ordered mutable sequences: indexing, slicing and list methods
# - [`02 - Tuples.ipynb`](03%20-%20Data%20Structures/02%20-%20Tuples.ipynb) - Ordered immutable sequences and unpacking
# - [`03 - Sets & Frozen Sets.ipynb`](03%20-%20Data%20Structures/03%20-%20Sets%20&%20Frozen%20Sets.ipynb) - Unique values, set operations and relationship tests
# - [`04 - Dictionaries.ipynb`](03%20-%20Data%20Structures/04%20-%20Dictionaries.ipynb) - Key-value pairs, dictionary methods, iteration and creation
# - [`05 - References, Identity & Copying.ipynb`](03%20-%20Data%20Structures/05%20-%20References,%20Identity%20&%20Copying.ipynb) - Names and objects, `is` vs `==`, mutability, shallow and deep copies
# - [`06 - Boolean & Containers Comparison.ipynb`](03%20-%20Data%20Structures/06%20-%20Boolean%20&%20Containers%20Comparison.ipynb) - Truthiness and a comparison of the built-in containers

# %% [markdown]
# <a id="p04"></a>
#
# ## 04 - Functions
# - [`01 - Functions Basics.ipynb`](04%20-%20Functions/01%20-%20Functions%20Basics.ipynb) - Defining and calling functions, parameters and arguments
# - [`02 - Return Statement.ipynb`](04%20-%20Functions/02%20-%20Return%20Statement.ipynb) - `return`, returning several values and `None`
# - [`03 - Parameters & Arguments.ipynb`](04%20-%20Functions/03%20-%20Parameters%20&%20Arguments.ipynb) - Positional and keyword arguments
# - [`04 - Default Parameters.ipynb`](04%20-%20Functions/04%20-%20Default%20Parameters.ipynb) - Default values and the mutable default trap
# - [`05 - Args Kwargs & Unpacking.ipynb`](04%20-%20Functions/05%20-%20Args%20Kwargs%20&%20Unpacking.ipynb) - `*args`, `**kwargs`, packing and unpacking
# - [`06 - Function Scope.ipynb`](04%20-%20Functions/06%20-%20Function%20Scope.ipynb) - Local and global scope, `global` and the LEGB rule
# - [`07 - Recursion.ipynb`](04%20-%20Functions/07%20-%20Recursion.ipynb) - Base case, recursive case and the call stack
# - [`08 - Lambda Functions.ipynb`](04%20-%20Functions/08%20-%20Lambda%20Functions.ipynb) - Small anonymous functions, and how they differ from `def`
# - [`09 - Decorators.ipynb`](04%20-%20Functions/09%20-%20Decorators.ipynb) - Wrapping functions with `@decorator`
# - [`10 - Docstrings.ipynb`](04%20-%20Functions/10%20-%20Docstrings.ipynb) - Documenting functions, classes and modules
# - [`11 - Type Hints Foundations.ipynb`](04%20-%20Functions/11%20-%20Type%20Hints%20Foundations.ipynb) - Variable and function annotations
# - [`12 - Collections, Union Types & Type Aliases.ipynb`](04%20-%20Functions/12%20-%20Collections,%20Union%20Types%20&%20Type%20Aliases.ipynb) - Generic collection types, unions, optional values and type aliases
# - [`13 - Coding Style (PEP 8).ipynb`](04%20-%20Functions/13%20-%20Coding%20Style%20%28PEP%208%29.ipynb) - Naming, layout, whitespace and common idioms

# %% [markdown]
# <a id="p05"></a>
#
# ## 05 - Errors, Debugging & Profiling
# - [`01 - Errors & Exceptions.ipynb`](05%20-%20Errors,%20Debugging%20&%20Profiling/01%20-%20Errors%20&%20Exceptions.ipynb) - Common exception types and `raise`
# - [`02 - Exception Handling.ipynb`](05%20-%20Errors,%20Debugging%20&%20Profiling/02%20-%20Exception%20Handling.ipynb) - `try`, `except`, `else` and `finally`
# - [`03 - Debugging.ipynb`](05%20-%20Errors,%20Debugging%20&%20Profiling/03%20-%20Debugging.ipynb) - Tracebacks, `assert`, `breakpoint()` and `pdb`
# - [`04 - Measuring Performance.ipynb`](05%20-%20Errors,%20Debugging%20&%20Profiling/04%20-%20Measuring%20Performance.ipynb) - `timeit`, `cProfile` and `tracemalloc`

# %% [markdown]
# <a id="p06"></a>
#
# ## 06 - Comprehensions, Iterators & Generators
# - [`01 - Comprehensions Foundations.ipynb`](06%20-%20Comprehensions,%20Iterators%20&%20Generators/01%20-%20Comprehensions%20Foundations.ipynb) - The four kinds of comprehensions and how they work
# - [`02 - Conditions, Multiple Loops & Nested Comprehensions.ipynb`](06%20-%20Comprehensions,%20Iterators%20&%20Generators/02%20-%20Conditions,%20Multiple%20Loops%20&%20Nested%20Comprehensions.ipynb) - Filters, conditional expressions, several loops and nesting
# - [`03 - Dict, Set & Generator Expressions.ipynb`](06%20-%20Comprehensions,%20Iterators%20&%20Generators/03%20-%20Dict,%20Set%20&%20Generator%20Expressions.ipynb) - Dict and set comprehensions, and lazy generator expressions
# - [`04 - Iterable vs Iterator.ipynb`](06%20-%20Comprehensions,%20Iterators%20&%20Generators/04%20-%20Iterable%20vs%20Iterator.ipynb) - `iter()`, `next()` and the iterator protocol
# - [`05 - Generators.ipynb`](06%20-%20Comprehensions,%20Iterators%20&%20Generators/05%20-%20Generators.ipynb) - `yield`, lazy evaluation and generator expressions
# - [`06 - Scope & the Walrus Operator.ipynb`](06%20-%20Comprehensions,%20Iterators%20&%20Generators/06%20-%20Scope%20&%20the%20Walrus%20Operator.ipynb) - Comprehension scope, closures and `:=`
# - [`07 - Performance, Readability & Best Practices.ipynb`](06%20-%20Comprehensions,%20Iterators%20&%20Generators/07%20-%20Performance,%20Readability%20&%20Best%20Practices.ipynb) - When to use comprehensions, and when not to

# %% [markdown]
# <a id="p07"></a>
#
# ## 07 - Standard Library Essentials
# - [`01 - math, statistics, decimal & fractions.ipynb`](07%20-%20Standard%20Library%20Essentials/01%20-%20math,%20statistics,%20decimal%20&%20fractions.ipynb) - Math functions, statistics and exact arithmetic
# - [`02 - random.ipynb`](07%20-%20Standard%20Library%20Essentials/02%20-%20random.ipynb) - Random numbers, choices and sampling, and `secrets`
# - [`03 - datetime & time.ipynb`](07%20-%20Standard%20Library%20Essentials/03%20-%20datetime%20&%20time.ipynb) - Dates, times, `timedelta`, formatting and parsing
# - [`04 - Counter & defaultdict.ipynb`](07%20-%20Standard%20Library%20Essentials/04%20-%20Counter%20&%20defaultdict.ipynb) - Counting with `Counter`, grouping with `defaultdict`
# - [`05 - deque, namedtuple, OrderedDict & ChainMap.ipynb`](07%20-%20Standard%20Library%20Essentials/05%20-%20deque,%20namedtuple,%20OrderedDict%20&%20ChainMap.ipynb) - Queues and stacks, named tuples and chained dictionaries
# - [`06 - functools.ipynb`](07%20-%20Standard%20Library%20Essentials/06%20-%20functools.ipynb) - `lru_cache`, `partial`, `reduce`, `wraps` and `singledispatch`

# %% [markdown]
# <a id="p08"></a>
#
# ## 08 - Itertools
# - [`01 - Itertools Foundations.ipynb`](08%20-%20Itertools/01%20-%20Itertools%20Foundations.ipynb) - What `itertools` offers and how to think in iterator pipelines
# - [`02 - Infinite Iterators.ipynb`](08%20-%20Itertools/02%20-%20Infinite%20Iterators.ipynb) - `count`, `cycle` and `repeat`
# - [`03 - Filtering & Slicing Iterators.ipynb`](08%20-%20Itertools/03%20-%20Filtering%20&%20Slicing%20Iterators.ipynb) - `islice`, `takewhile`, `dropwhile`, `filterfalse` and `compress`
# - [`04 - Chaining, Zipping & Mapping.ipynb`](08%20-%20Itertools/04%20-%20Chaining,%20Zipping%20&%20Mapping.ipynb) - `chain`, `zip_longest` and `starmap`
# - [`05 - Accumulate, Pairwise, Batched & Tee.ipynb`](08%20-%20Itertools/05%20-%20Accumulate,%20Pairwise,%20Batched%20&%20Tee.ipynb) - Running results, neighbours, chunks and copies of an iterator
# - [`06 - Grouping with groupby.ipynb`](08%20-%20Itertools/06%20-%20Grouping%20with%20groupby.ipynb) - Grouping consecutive items with `groupby`
# - [`07 - Combinatoric Iterators.ipynb`](08%20-%20Itertools/07%20-%20Combinatoric%20Iterators.ipynb) - `product`, `permutations` and `combinations`
# - [`08 - Recipes, Patterns & Best Practices.ipynb`](08%20-%20Itertools/08%20-%20Recipes,%20Patterns%20&%20Best%20Practices.ipynb) - Building your own tools and avoiding common pitfalls

# %% [markdown]
# <a id="p09"></a>
#
# ## 09 - Files & Data Formats
# - [`01 - File Handling.ipynb`](09%20-%20Files%20&%20Data%20Formats/01%20-%20File%20Handling.ipynb) - Opening, reading and writing files, and file modes
# - [`02 - Additional File Methods.ipynb`](09%20-%20Files%20&%20Data%20Formats/02%20-%20Additional%20File%20Methods.ipynb) - `tell`, `seek`, `truncate`, `flush` and file attributes
# - [`03 - Paths with pathlib.ipynb`](09%20-%20Files%20&%20Data%20Formats/03%20-%20Paths%20with%20pathlib.ipynb) - Paths as objects: joining, searching, reading and writing
# - [`04 - os, sys & shutil.ipynb`](09%20-%20Files%20&%20Data%20Formats/04%20-%20os,%20sys%20&%20shutil.ipynb) - Operating system, interpreter and file-copying tools
# - [`05 - JSON Files.ipynb`](09%20-%20Files%20&%20Data%20Formats/05%20-%20JSON%20Files.ipynb) - Reading and writing JSON
# - [`06 - CSV Files.ipynb`](09%20-%20Files%20&%20Data%20Formats/06%20-%20CSV%20Files.ipynb) - Reading and writing CSV

# %% [markdown]
# <a id="p10"></a>
#
# ## 10 - Regular Expressions
# - [`01 - Regular Expressions Foundations.ipynb`](10%20-%20Regular%20Expressions/01%20-%20Regular%20Expressions%20Foundations.ipynb) - What regex is, raw strings and the main `re` functions
# - [`02 - Regex Syntax, Character Classes & Quantifiers.ipynb`](10%20-%20Regular%20Expressions/02%20-%20Regex%20Syntax,%20Character%20Classes%20&%20Quantifiers.ipynb) - Characters, classes, anchors and quantifiers
# - [`03 - Regex Groups, Alternation & Assertions.ipynb`](10%20-%20Regular%20Expressions/03%20-%20Regex%20Groups,%20Alternation%20&%20Assertions.ipynb) - Groups, alternation, backreferences and lookarounds
# - [`04 - Regex Functions, Match Objects & Replacement.ipynb`](10%20-%20Regular%20Expressions/04%20-%20Regex%20Functions,%20Match%20Objects%20&%20Replacement.ipynb) - `search`, `match`, `findall`, `sub`, `split` and compiled patterns
# - [`05 - Regex Flags, Performance & Best Practices.ipynb`](10%20-%20Regular%20Expressions/05%20-%20Regex%20Flags,%20Performance%20&%20Best%20Practices.ipynb) - Flags, performance and practical advice

# %% [markdown]
# <a id="p11"></a>
#
# ## 11 - Object Oriented Programming
# - [`01 - OOP Foundations.ipynb`](11%20-%20Object%20Oriented%20Programming/01%20-%20OOP%20Foundations.ipynb) - Classes, objects and the vocabulary of OOP
# - [`02 - Classes, Instances & __init__.ipynb`](11%20-%20Object%20Oriented%20Programming/02%20-%20Classes,%20Instances%20&%20__init__.ipynb) - Class syntax, `__init__` and `self`
# - [`03 - Attributes & Methods.ipynb`](11%20-%20Object%20Oriented%20Programming/03%20-%20Attributes%20&%20Methods.ipynb) - Instance and class attributes, methods, lookup and shadowing
# - [`04 - Encapsulation & Properties.ipynb`](11%20-%20Object%20Oriented%20Programming/04%20-%20Encapsulation%20&%20Properties.ipynb) - Private naming and `@property`
# - [`05 - Class & Static Methods.ipynb`](11%20-%20Object%20Oriented%20Programming/05%20-%20Class%20&%20Static%20Methods.ipynb) - `@classmethod`, `@staticmethod` and alternative constructors
# - [`06 - Inheritance & super.ipynb`](11%20-%20Object%20Oriented%20Programming/06%20-%20Inheritance%20&%20super.ipynb) - Inheritance, overriding and `super()`
# - [`07 - Custom Exceptions & Chaining.ipynb`](11%20-%20Object%20Oriented%20Programming/07%20-%20Custom%20Exceptions%20&%20Chaining.ipynb) - Your own exceptions, `raise from`, notes and exception groups
# - [`08 - Multiple Inheritance, MRO & Mixins.ipynb`](11%20-%20Object%20Oriented%20Programming/08%20-%20Multiple%20Inheritance,%20MRO%20&%20Mixins.ipynb) - Method resolution order and mixins
# - [`09 - Polymorphism, Duck Typing & Composition.ipynb`](11%20-%20Object%20Oriented%20Programming/09%20-%20Polymorphism,%20Duck%20Typing%20&%20Composition.ipynb) - Common interfaces, duck typing and composition
# - [`10 - Abstract Base Classes.ipynb`](11%20-%20Object%20Oriented%20Programming/10%20-%20Abstract%20Base%20Classes.ipynb) - `ABC` and `@abstractmethod`
# - [`11 - Dunder Methods & Operator Overloading.ipynb`](11%20-%20Object%20Oriented%20Programming/11%20-%20Dunder%20Methods%20&%20Operator%20Overloading.ipynb) - Special methods such as `__str__`, `__eq__` and `__add__`
# - [`12 - Context Managers.ipynb`](11%20-%20Object%20Oriented%20Programming/12%20-%20Context%20Managers.ipynb) - `with`, `__enter__` / `__exit__` and `@contextmanager`
# - [`13 - Object Model, Descriptors & __slots__.ipynb`](11%20-%20Object%20Oriented%20Programming/13%20-%20Object%20Model,%20Descriptors%20&%20__slots__.ipynb) - `__new__`, descriptors, attribute hooks and `__slots__`
# - [`14 - Dataclasses & Enums.ipynb`](11%20-%20Object%20Oriented%20Programming/14%20-%20Dataclasses%20&%20Enums.ipynb) - `@dataclass` and `Enum`
# - [`15 - Class Patterns.ipynb`](11%20-%20Object%20Oriented%20Programming/15%20-%20Class%20Patterns.ipynb) - Matching objects and enums with `match`
# - [`16 - OOP Design, Advanced Patterns & Best Practices.ipynb`](11%20-%20Object%20Oriented%20Programming/16%20-%20OOP%20Design,%20Advanced%20Patterns%20&%20Best%20Practices.ipynb) - Design guidelines and common patterns

# %% [markdown]
# <a id="p12"></a>
#
# ## 12 - Advanced Type Hinting
# - [`01 - TypeVar, Generic, Literal, Final & ClassVar.ipynb`](12%20-%20Advanced%20Type%20Hinting/01%20-%20TypeVar,%20Generic,%20Literal,%20Final%20&%20ClassVar.ipynb) - Generics and special type forms
# - [`02 - Protocols, TypedDict, NamedTuple & Callable.ipynb`](12%20-%20Advanced%20Type%20Hinting/02%20-%20Protocols,%20TypedDict,%20NamedTuple%20&%20Callable.ipynb) - Structural typing and typed data shapes
# - [`03 - Advanced Type Hints_ Self, TypeGuard, overload, ParamSpec & Annotated.ipynb`](12%20-%20Advanced%20Type%20Hinting/03%20-%20Advanced%20Type%20Hints_%20Self,%20TypeGuard,%20overload,%20ParamSpec%20&%20Annotated.ipynb) - `Self`, `TypeGuard`, `overload`, `ParamSpec` and `Annotated`
# - [`04 - Typing Tools, Runtime Introspection & Python 3.14 Notes.ipynb`](12%20-%20Advanced%20Type%20Hinting/04%20-%20Typing%20Tools,%20Runtime%20Introspection%20&%20Python%203.14%20Notes.ipynb) - `cast`, `get_type_hints`, annotations at runtime and Python 3.14 changes

# %% [markdown]
# <a id="p13"></a>
#
# ## 13 - Building Real Programs
# - [`01 - Packages & the __main__ Guard.ipynb`](13%20-%20Building%20Real%20Programs/01%20-%20Packages%20&%20the%20__main__%20Guard.ipynb) - Packages, `__init__.py`, relative imports and the `__main__` guard
# - [`02 - Command-Line Arguments.ipynb`](13%20-%20Building%20Real%20Programs/02%20-%20Command-Line%20Arguments.ipynb) - `sys.argv` and `argparse`
# - [`03 - External Packages.ipynb`](13%20-%20Building%20Real%20Programs/03%20-%20External%20Packages.ipynb) - Installing packages with `pip`
# - [`04 - Logging.ipynb`](13%20-%20Building%20Real%20Programs/04%20-%20Logging.ipynb) - Levels, handlers and formatters
# - [`05 - Unit Testing with unittest.ipynb`](13%20-%20Building%20Real%20Programs/05%20-%20Unit%20Testing%20with%20unittest.ipynb) - Test cases, assertions, fixtures and `subTest`
# - [`06 - doctest.ipynb`](13%20-%20Building%20Real%20Programs/06%20-%20doctest.ipynb) - Tests written inside docstrings

# %% [markdown]
# <a id="p14"></a>
#
# ## 14 - Quick References
# - [`01 - Keywords.ipynb`](14%20-%20Quick%20References/01%20-%20Keywords.ipynb) - All 35 keywords with examples
# - [`02 - Built-in Functions.ipynb`](14%20-%20Quick%20References/02%20-%20Built-in%20Functions.ipynb) - Built-in functions by category
# - [`03 - Methods of Built-in Types.ipynb`](14%20-%20Quick%20References/03%20-%20Methods%20of%20Built-in%20Types.ipynb) - Every method of `str`, `list`, `tuple`, `dict` and `set`, with examples and results
# - [`04 - Task Index.ipynb`](14%20-%20Quick%20References/04%20-%20Task%20Index.ipynb) - Find the right tool by describing what you want to do
