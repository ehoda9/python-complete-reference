# %% [markdown]
# # Quick References => Task Index: How Do I...?
#
# Find what to use by describing what you want to do. Each row shows the tool and where it is explained.
#
# | Category | Tasks |
# |---|---|
# | Text | 34 |
# | Numbers | 18 |
# | Lists | 29 |
# | Dictionaries | 14 |
# | Sets and tuples | 6 |
# | Control flow | 11 |
# | Functions | 10 |
# | Errors and debugging | 11 |
# | Files and data | 14 |
# | Dates and time | 5 |
# | Classes | 11 |
# | Regular expressions | 6 |
# | Programs and projects | 10 |
#
# ---
#
# ## Text
#
# | I want to... | Use | Where |
# |---|---|---|
# | Remove spaces from both ends | `text.strip()` | [Data Types](../01%20-%20Python%20Basics/03%20-%20Data%20Types.ipynb) |
# | Remove spaces only at the start or the end | `text.lstrip()`, `text.rstrip()` | [Data Types](../01%20-%20Python%20Basics/03%20-%20Data%20Types.ipynb) |
# | Change to upper or lower case | `text.upper()`, `text.lower()` | [Data Types](../01%20-%20Python%20Basics/03%20-%20Data%20Types.ipynb) |
# | Capitalize every word | `text.title()` | [Data Types](../01%20-%20Python%20Basics/03%20-%20Data%20Types.ipynb) |
# | Compare text ignoring case | `a.casefold() == b.casefold()` | [Data Types](../01%20-%20Python%20Basics/03%20-%20Data%20Types.ipynb) |
# | Check how a string starts or ends | `text.startswith("ab")`, `text.endswith(".py")` | [Data Types](../01%20-%20Python%20Basics/03%20-%20Data%20Types.ipynb) |
# | Check if a substring is inside a string | `"ab" in text` | [Operators](../01%20-%20Python%20Basics/04%20-%20Operators.ipynb) |
# | Find the position of a substring | `text.find("ab")` (-1 if missing), `text.index("ab")` (error if missing) | [Data Types](../01%20-%20Python%20Basics/03%20-%20Data%20Types.ipynb) |
# | Count how many times a substring appears | `text.count("a")` | [Data Types](../01%20-%20Python%20Basics/03%20-%20Data%20Types.ipynb) |
# | Replace part of a string | `text.replace("a", "b")` | [Data Types](../01%20-%20Python%20Basics/03%20-%20Data%20Types.ipynb) |
# | Replace several characters at once | `text.translate(str.maketrans("ab", "xy"))` | [Data Types](../01%20-%20Python%20Basics/03%20-%20Data%20Types.ipynb) |
# | Remove a prefix or a suffix | `text.removeprefix("a")`, `text.removesuffix(".txt")` | [Data Types](../01%20-%20Python%20Basics/03%20-%20Data%20Types.ipynb) |
# | Split a string into a list | `text.split(",")`, `text.split()` (on whitespace) | [Data Types](../01%20-%20Python%20Basics/03%20-%20Data%20Types.ipynb) |
# | Split a string into lines | `text.splitlines()` | [Data Types](../01%20-%20Python%20Basics/03%20-%20Data%20Types.ipynb) |
# | Split at the first separator only | `text.partition("=")` | [Data Types](../01%20-%20Python%20Basics/03%20-%20Data%20Types.ipynb) |
# | Join a list of strings into one string | `", ".join(words)` | [Data Types](../01%20-%20Python%20Basics/03%20-%20Data%20Types.ipynb) |
# | Check if a string is only digits or only letters | `text.isdigit()`, `text.isalpha()`, `text.isalnum()` | [Data Types](../01%20-%20Python%20Basics/03%20-%20Data%20Types.ipynb) |
# | Pad a number with zeros | `"42".zfill(5)`, `f"{42:05d}"` | [Data Types](../01%20-%20Python%20Basics/03%20-%20Data%20Types.ipynb) |
# | Center or align text in a width | `text.center(20)`, `text.ljust(20)`, `text.rjust(20)` | [Data Types](../01%20-%20Python%20Basics/03%20-%20Data%20Types.ipynb) |
# | Get one character or a slice | `text[0]`, `text[-1]`, `text[1:4]` | [Data Types](../01%20-%20Python%20Basics/03%20-%20Data%20Types.ipynb) |
# | Reverse a string | `text[::-1]` | [Data Types](../01%20-%20Python%20Basics/03%20-%20Data%20Types.ipynb) |
# | Repeat a string | `"ab" * 3` | [Operators](../01%20-%20Python%20Basics/04%20-%20Operators.ipynb) |
# | Print a tab, a new line or a quote | `"a\tb"`, `"a\nb"`, `"say \"hi\""` | [Data Types](../01%20-%20Python%20Basics/03%20-%20Data%20Types.ipynb) |
# | Put a value inside a string | `f"{name} is {age}"` | [String Formatting](../01%20-%20Python%20Basics/07%20-%20String%20Formatting.ipynb) |
# | Format a number with 2 decimals | `f"{x:.2f}"` | [String Formatting](../01%20-%20Python%20Basics/07%20-%20String%20Formatting.ipynb) |
# | Add a thousands separator | `f"{n:,}"` | [String Formatting](../01%20-%20Python%20Basics/07%20-%20String%20Formatting.ipynb) |
# | Show a percentage | `f"{ratio:.1%}"` | [String Formatting](../01%20-%20Python%20Basics/07%20-%20String%20Formatting.ipynb) |
# | Print a variable name and value while debugging | `f"{x=}"` | [String Formatting](../01%20-%20Python%20Basics/07%20-%20String%20Formatting.ipynb) |
# | Align columns in a printed table | `f"{name:<10}{qty:>5}"` | [String Formatting](../01%20-%20Python%20Basics/07%20-%20String%20Formatting.ipynb) |
# | Convert text to a number | `int("42")`, `float("3.5")` | [Type Conversion](../01%20-%20Python%20Basics/05%20-%20Type%20Conversion.ipynb) |
# | Convert a number to text | `str(42)` | [Type Conversion](../01%20-%20Python%20Basics/05%20-%20Type%20Conversion.ipynb) |
# | Get the code of a character, or the character of a code | `ord("a")`, `chr(97)` | [Built-in Functions](../14%20-%20Quick%20References/02%20-%20Built-in%20Functions.ipynb) |
# | Convert text to bytes and back | `text.encode("utf-8")`, `data.decode("utf-8")` | [Data Types](../01%20-%20Python%20Basics/03%20-%20Data%20Types.ipynb) |
# | Read what the user types | `input("Name: ")` | [User Input](../01%20-%20Python%20Basics/06%20-%20User%20Input.ipynb) |
#
# ## Numbers
#
# | I want to... | Use | Where |
# |---|---|---|
# | Round a number | `round(x, 2)` | [Built-in Functions](../14%20-%20Quick%20References/02%20-%20Built-in%20Functions.ipynb) |
# | Round down or up to a whole number | `math.floor(x)`, `math.ceil(x)` | [`math`, `statistics`, `decimal` & `fractions`](../07%20-%20Standard%20Library%20Essentials/01%20-%20math,%20statistics,%20decimal%20%26%20fractions.ipynb) |
# | Get the absolute value | `abs(x)` | [Built-in Functions](../14%20-%20Quick%20References/02%20-%20Built-in%20Functions.ipynb) |
# | Power and square root | `x ** 2`, `math.sqrt(x)` | [`math`, `statistics`, `decimal` & `fractions`](../07%20-%20Standard%20Library%20Essentials/01%20-%20math,%20statistics,%20decimal%20%26%20fractions.ipynb) |
# | Get the quotient and the remainder | `divmod(a, b)`, `a // b`, `a % b` | [Built-in Functions](../14%20-%20Quick%20References/02%20-%20Built-in%20Functions.ipynb) |
# | Find the smallest, the largest or the sum | `min(items)`, `max(items)`, `sum(items)` | [Built-in Functions](../14%20-%20Quick%20References/02%20-%20Built-in%20Functions.ipynb) |
# | Calculate the average or the median | `statistics.mean(items)`, `statistics.median(items)` | [`math`, `statistics`, `decimal` & `fractions`](../07%20-%20Standard%20Library%20Essentials/01%20-%20math,%20statistics,%20decimal%20%26%20fractions.ipynb) |
# | Compare floats safely | `math.isclose(a, b)` | [`math`, `statistics`, `decimal` & `fractions`](../07%20-%20Standard%20Library%20Essentials/01%20-%20math,%20statistics,%20decimal%20%26%20fractions.ipynb) |
# | Calculate with exact decimals (money) | `Decimal("0.1") + Decimal("0.2")` | [`math`, `statistics`, `decimal` & `fractions`](../07%20-%20Standard%20Library%20Essentials/01%20-%20math,%20statistics,%20decimal%20%26%20fractions.ipynb) |
# | Greatest common divisor, factorial, combinations | `math.gcd(a, b)`, `math.factorial(n)`, `math.comb(n, k)` | [`math`, `statistics`, `decimal` & `fractions`](../07%20-%20Standard%20Library%20Essentials/01%20-%20math,%20statistics,%20decimal%20%26%20fractions.ipynb) |
# | Convert to binary, octal or hexadecimal text | `bin(10)`, `oct(8)`, `hex(255)` | [Built-in Functions](../14%20-%20Quick%20References/02%20-%20Built-in%20Functions.ipynb) |
# | Read a number written in another base | `int("ff", 16)` | [Built-in Functions](../14%20-%20Quick%20References/02%20-%20Built-in%20Functions.ipynb) |
# | Random integer in a range (both ends included) | `random.randint(1, 6)` | [`random`](../07%20-%20Standard%20Library%20Essentials/02%20-%20random.ipynb) |
# | Random float between 0 and 1 | `random.random()` | [`random`](../07%20-%20Standard%20Library%20Essentials/02%20-%20random.ipynb) |
# | Pick a random item from a list | `random.choice(items)` | [`random`](../07%20-%20Standard%20Library%20Essentials/02%20-%20random.ipynb) |
# | Pick several different items | `random.sample(items, 3)` | [`random`](../07%20-%20Standard%20Library%20Essentials/02%20-%20random.ipynb) |
# | Shuffle a list in place | `random.shuffle(items)` | [`random`](../07%20-%20Standard%20Library%20Essentials/02%20-%20random.ipynb) |
# | Make random results repeatable | `random.seed(42)` | [`random`](../07%20-%20Standard%20Library%20Essentials/02%20-%20random.ipynb) |
#
# ## Lists
#
# | I want to... | Use | Where |
# |---|---|---|
# | Add an item at the end | `items.append(x)` | [Lists](../03%20-%20Data%20Structures/01%20-%20Lists.ipynb) |
# | Add several items at the end | `items.extend(more)` | [Lists](../03%20-%20Data%20Structures/01%20-%20Lists.ipynb) |
# | Insert an item at a position | `items.insert(i, x)` | [Lists](../03%20-%20Data%20Structures/01%20-%20Lists.ipynb) |
# | Remove an item by value | `items.remove(x)` | [Lists](../03%20-%20Data%20Structures/01%20-%20Lists.ipynb) |
# | Remove an item by position and get it | `items.pop(i)` | [Lists](../03%20-%20Data%20Structures/01%20-%20Lists.ipynb) |
# | Delete by position or slice | `del items[i]`, `del items[1:3]` | [Lists](../03%20-%20Data%20Structures/01%20-%20Lists.ipynb) |
# | Empty a list | `items.clear()` | [Lists](../03%20-%20Data%20Structures/01%20-%20Lists.ipynb) |
# | Sort a list in place | `items.sort()` | [Lists](../03%20-%20Data%20Structures/01%20-%20Lists.ipynb) |
# | Get a sorted copy and keep the original | `sorted(items)` | [Built-in Functions](../14%20-%20Quick%20References/02%20-%20Built-in%20Functions.ipynb) |
# | Sort by a rule (length, a field, ...) | `sorted(items, key=len)` | [Built-in Functions](../14%20-%20Quick%20References/02%20-%20Built-in%20Functions.ipynb) |
# | Sort from largest to smallest | `sorted(items, reverse=True)` | [Built-in Functions](../14%20-%20Quick%20References/02%20-%20Built-in%20Functions.ipynb) |
# | Reverse a list | `items.reverse()`, `items[::-1]`, `reversed(items)` | [Lists](../03%20-%20Data%20Structures/01%20-%20Lists.ipynb) |
# | Copy a list | `items.copy()`, `items[:]`, `list(items)` | [Lists](../03%20-%20Data%20Structures/01%20-%20Lists.ipynb) |
# | Count an item or find its position | `items.count(x)`, `items.index(x)` | [Lists](../03%20-%20Data%20Structures/01%20-%20Lists.ipynb) |
# | Get the first, the last or a range of items | `items[0]`, `items[-1]`, `items[:3]` | [Lists](../03%20-%20Data%20Structures/01%20-%20Lists.ipynb) |
# | Loop with the index and the value | `for i, x in enumerate(items):` | [Built-in Functions](../14%20-%20Quick%20References/02%20-%20Built-in%20Functions.ipynb) |
# | Loop over two lists together | `for a, b in zip(xs, ys):` | [Built-in Functions](../14%20-%20Quick%20References/02%20-%20Built-in%20Functions.ipynb) |
# | Check if any or all items pass a test | `any(x > 0 for x in items)`, `all(...)` | [Built-in Functions](../14%20-%20Quick%20References/02%20-%20Built-in%20Functions.ipynb) |
# | Build a new list from another | `[x * 2 for x in items]` | [Comprehensions Foundations](../06%20-%20Comprehensions,%20Iterators%20%26%20Generators/01%20-%20Comprehensions%20Foundations.ipynb) |
# | Keep only some items | `[x for x in items if x > 0]` | [Comprehensions Foundations](../06%20-%20Comprehensions,%20Iterators%20%26%20Generators/01%20-%20Comprehensions%20Foundations.ipynb) |
# | Flatten a list of lists | `[x for row in rows for x in row]` | [Conditions, Multiple Loops & Nested Comprehensions](../06%20-%20Comprehensions,%20Iterators%20%26%20Generators/02%20-%20Conditions,%20Multiple%20Loops%20%26%20Nested%20Comprehensions.ipynb) |
# | Remove duplicates and keep the order | `list(dict.fromkeys(items))` | [Dictionaries](../03%20-%20Data%20Structures/04%20-%20Dictionaries.ipynb) |
# | Remove duplicates (order does not matter) | `list(set(items))` | [Sets & Frozen Sets](../03%20-%20Data%20Structures/03%20-%20Sets%20%26%20Frozen%20Sets.ipynb) |
# | Split a list into chunks | `itertools.batched(items, 3)` | [Accumulate, Pairwise, Batched & Tee](../08%20-%20Itertools/05%20-%20Accumulate,%20Pairwise,%20Batched%20%26%20Tee.ipynb) |
# | Get every pair of neighbours | `itertools.pairwise(items)` | [Accumulate, Pairwise, Batched & Tee](../08%20-%20Itertools/05%20-%20Accumulate,%20Pairwise,%20Batched%20%26%20Tee.ipynb) |
# | Get a running total | `itertools.accumulate(items)` | [Accumulate, Pairwise, Batched & Tee](../08%20-%20Itertools/05%20-%20Accumulate,%20Pairwise,%20Batched%20%26%20Tee.ipynb) |
# | Get all combinations or permutations | `itertools.combinations(items, 2)`, `itertools.permutations(items)` | [Combinatoric Iterators](../08%20-%20Itertools/07%20-%20Combinatoric%20Iterators.ipynb) |
# | Group consecutive equal items | `itertools.groupby(items)` | [Grouping with `groupby`](../08%20-%20Itertools/06%20-%20Grouping%20with%20groupby.ipynb) |
# | Count how often each item appears | `Counter(items)` | [Counter & `defaultdict`](../07%20-%20Standard%20Library%20Essentials/04%20-%20Counter%20%26%20defaultdict.ipynb) |
#
# ## Dictionaries
#
# | I want to... | Use | Where |
# |---|---|---|
# | Read a value with a default | `d.get(key, default)` | [Dictionaries](../03%20-%20Data%20Structures/04%20-%20Dictionaries.ipynb) |
# | Add or change one value | `d[key] = value` | [Dictionaries](../03%20-%20Data%20Structures/04%20-%20Dictionaries.ipynb) |
# | Add or change several values | `d.update(other)` | [Dictionaries](../03%20-%20Data%20Structures/04%20-%20Dictionaries.ipynb) |
# | Delete a key | `del d[key]`, `d.pop(key)` | [Dictionaries](../03%20-%20Data%20Structures/04%20-%20Dictionaries.ipynb) |
# | Check if a key exists | `key in d` | [Operators](../01%20-%20Python%20Basics/04%20-%20Operators.ipynb) |
# | Loop over keys, values or pairs | `d.keys()`, `d.values()`, `d.items()` | [Dictionaries](../03%20-%20Data%20Structures/04%20-%20Dictionaries.ipynb) |
# | Merge two dictionaries | `{**a, **b}`, `a.update(b)` | [`*args`, `**kwargs` & Unpacking](../04%20-%20Functions/05%20-%20Args%20Kwargs%20%26%20Unpacking.ipynb) |
# | Build a dictionary from two lists | `dict(zip(keys, values))` | [Built-in Functions](../14%20-%20Quick%20References/02%20-%20Built-in%20Functions.ipynb) |
# | Create a dictionary with the same value for many keys | `dict.fromkeys(keys, 0)` | [Dictionaries](../03%20-%20Data%20Structures/04%20-%20Dictionaries.ipynb) |
# | Swap keys and values | `{v: k for k, v in d.items()}` | [Dict, Set & Generator Expressions](../06%20-%20Comprehensions,%20Iterators%20%26%20Generators/03%20-%20Dict,%20Set%20%26%20Generator%20Expressions.ipynb) |
# | Sort a dictionary by its values | `sorted(d.items(), key=lambda kv: kv[1])` | [Lambda Functions](../04%20-%20Functions/08%20-%20Lambda%20Functions.ipynb) |
# | Group items by a key | `defaultdict(list)` | [Counter & `defaultdict`](../07%20-%20Standard%20Library%20Essentials/04%20-%20Counter%20%26%20defaultdict.ipynb) |
# | Combine settings with priorities | `ChainMap(cli, env, defaults)` | [`deque`, `namedtuple`, `OrderedDict` & `ChainMap`](../07%20-%20Standard%20Library%20Essentials/05%20-%20deque,%20namedtuple,%20OrderedDict%20%26%20ChainMap.ipynb) |
# | Copy a dictionary (also the nested parts) | `d.copy()`, `copy.deepcopy(d)` | [References, Identity & Copying](../03%20-%20Data%20Structures/05%20-%20References,%20Identity%20%26%20Copying.ipynb) |
#
# ## Sets and tuples
#
# | I want to... | Use | Where |
# |---|---|---|
# | Get the unique values | `set(items)` | [Sets & Frozen Sets](../03%20-%20Data%20Structures/03%20-%20Sets%20%26%20Frozen%20Sets.ipynb) |
# | Common items, all items, items only in one | `a & b`, `a \| b`, `a - b` | [Sets & Frozen Sets](../03%20-%20Data%20Structures/03%20-%20Sets%20%26%20Frozen%20Sets.ipynb) |
# | Test if one set is inside another | `a.issubset(b)` | [Sets & Frozen Sets](../03%20-%20Data%20Structures/03%20-%20Sets%20%26%20Frozen%20Sets.ipynb) |
# | Unpack values into names | `a, b = pair`, `first, *rest = items` | [Tuples](../03%20-%20Data%20Structures/02%20-%20Tuples.ipynb) |
# | Make a record with named fields | `Point = namedtuple("Point", ["x", "y"])` | [`deque`, `namedtuple`, `OrderedDict` & `ChainMap`](../07%20-%20Standard%20Library%20Essentials/05%20-%20deque,%20namedtuple,%20OrderedDict%20%26%20ChainMap.ipynb) |
# | Use a queue or a stack | `deque()` with `append` and `popleft` / `pop` | [`deque`, `namedtuple`, `OrderedDict` & `ChainMap`](../07%20-%20Standard%20Library%20Essentials/05%20-%20deque,%20namedtuple,%20OrderedDict%20%26%20ChainMap.ipynb) |
#
# ## Control flow
#
# | I want to... | Use | Where |
# |---|---|---|
# | Run code only if a condition is true | `if x > 0:` ... `elif` ... `else:` | [If, Elif, Else](../02%20-%20Control%20Flow/01%20-%20If%20Elif%20Else.ipynb) |
# | Choose between two values in one line | `a if condition else b` | [If, Elif, Else](../02%20-%20Control%20Flow/01%20-%20If%20Elif%20Else.ipynb) |
# | Choose by the shape or value of data | `match value:` ... `case ...:` | [`match` / `case`](../02%20-%20Control%20Flow/04%20-%20Match%20Case.ipynb) |
# | Repeat something N times | `for _ in range(n):` | [For Loop](../02%20-%20Control%20Flow/03%20-%20For%20Loop.ipynb) |
# | Count with a start, a stop and a step | `range(start, stop, step)` | [For Loop](../02%20-%20Control%20Flow/03%20-%20For%20Loop.ipynb) |
# | Repeat until a condition changes | `while condition:` | [While Loop](../02%20-%20Control%20Flow/02%20-%20While%20Loop.ipynb) |
# | Stop a loop or skip to the next round | `break`, `continue` | [For Loop](../02%20-%20Control%20Flow/03%20-%20For%20Loop.ipynb) |
# | Loop in reverse order | `for x in reversed(items):` | [Built-in Functions](../14%20-%20Quick%20References/02%20-%20Built-in%20Functions.ipynb) |
# | Produce values one at a time (lazily) | `yield` inside a function | [Generators](../06%20-%20Comprehensions,%20Iterators%20%26%20Generators/05%20-%20Generators.ipynb) |
# | Chain several iterables into one | `itertools.chain(a, b)` | [Chaining, Zipping & Mapping](../08%20-%20Itertools/04%20-%20Chaining,%20Zipping%20%26%20Mapping.ipynb) |
# | Take the first N items of any iterable | `itertools.islice(it, n)` | [Filtering & Slicing Iterators](../08%20-%20Itertools/03%20-%20Filtering%20%26%20Slicing%20Iterators.ipynb) |
#
# ## Functions
#
# | I want to... | Use | Where |
# |---|---|---|
# | Give a parameter a default value | `def f(x=1):` | [Default Parameters](../04%20-%20Functions/04%20-%20Default%20Parameters.ipynb) |
# | Accept any number of arguments | `def f(*args, **kwargs):` | [`*args`, `**kwargs` & Unpacking](../04%20-%20Functions/05%20-%20Args%20Kwargs%20%26%20Unpacking.ipynb) |
# | Return several values | `return a, b` | [Return Statement](../04%20-%20Functions/02%20-%20Return%20Statement.ipynb) |
# | Write a small throwaway function | `lambda x: x * 2` | [Lambda Functions](../04%20-%20Functions/08%20-%20Lambda%20Functions.ipynb) |
# | Change a variable of an outer function | `nonlocal count` | [Function Scope](../04%20-%20Functions/06%20-%20Function%20Scope.ipynb) |
# | Add behavior to a function | `@decorator` | [Decorators](../04%20-%20Functions/09%20-%20Decorators.ipynb) |
# | Remember the results of a function (cache) | `@functools.lru_cache` | [`functools`](../07%20-%20Standard%20Library%20Essentials/06%20-%20functools.ipynb) |
# | Fix some arguments of a function | `functools.partial(f, base=2)` | [`functools`](../07%20-%20Standard%20Library%20Essentials/06%20-%20functools.ipynb) |
# | Document a function | `"""Explain what it does."""` | [Docstrings](../04%20-%20Functions/10%20-%20Docstrings.ipynb) |
# | Describe the types of parameters and results | `def f(x: int) -> str:` | [Type Hints Foundations](../04%20-%20Functions/11%20-%20Type%20Hints%20Foundations.ipynb) |
#
# ## Errors and debugging
#
# | I want to... | Use | Where |
# |---|---|---|
# | Catch an error | `try:` ... `except ValueError:` | [Exception Handling](../05%20-%20Errors,%20Debugging%20%26%20Profiling/02%20-%20Exception%20Handling.ipynb) |
# | Run cleanup code whatever happens | `finally:` | [Exception Handling](../05%20-%20Errors,%20Debugging%20%26%20Profiling/02%20-%20Exception%20Handling.ipynb) |
# | Raise an error myself | `raise ValueError("message")` | [Errors & Exceptions](../05%20-%20Errors,%20Debugging%20%26%20Profiling/01%20-%20Errors%20%26%20Exceptions.ipynb) |
# | Define my own error type | `class MyError(Exception):` | [Custom Exceptions & Chaining](../11%20-%20Object%20Oriented%20Programming/07%20-%20Custom%20Exceptions%20%26%20Chaining.ipynb) |
# | Keep the original error when raising a new one | `raise NewError("...") from error` | [Custom Exceptions & Chaining](../11%20-%20Object%20Oriented%20Programming/07%20-%20Custom%20Exceptions%20%26%20Chaining.ipynb) |
# | Read a traceback | read it from the bottom up | [Debugging](../05%20-%20Errors,%20Debugging%20%26%20Profiling/03%20-%20Debugging.ipynb) |
# | Stop the program and inspect it | `breakpoint()` | [Debugging](../05%20-%20Errors,%20Debugging%20%26%20Profiling/03%20-%20Debugging.ipynb) |
# | Check an assumption | `assert x > 0, "message"` | [Debugging](../05%20-%20Errors,%20Debugging%20%26%20Profiling/03%20-%20Debugging.ipynb) |
# | Write log messages | `logging.info("message")` | [Logging](../13%20-%20Building%20Real%20Programs/04%20-%20Logging.ipynb) |
# | Measure how long code takes | `timeit.timeit(stmt, number=1000)` | [Measuring Performance](../05%20-%20Errors,%20Debugging%20%26%20Profiling/04%20-%20Measuring%20Performance.ipynb) |
# | Find the slow functions | `cProfile` | [Measuring Performance](../05%20-%20Errors,%20Debugging%20%26%20Profiling/04%20-%20Measuring%20Performance.ipynb) |
#
# ## Files and data
#
# | I want to... | Use | Where |
# |---|---|---|
# | Read a whole text file | `Path(p).read_text()` | [Paths with `pathlib`](../09%20-%20Files%20%26%20Data%20Formats/03%20-%20Paths%20with%20pathlib.ipynb) |
# | Read a file line by line | `for line in file:` | [File Handling](../09%20-%20Files%20%26%20Data%20Formats/01%20-%20File%20Handling.ipynb) |
# | Write or append text to a file | `open(p, "w")`, `open(p, "a")` | [File Handling](../09%20-%20Files%20%26%20Data%20Formats/01%20-%20File%20Handling.ipynb) |
# | Make sure a file is closed | `with open(p) as file:` | [File Handling](../09%20-%20Files%20%26%20Data%20Formats/01%20-%20File%20Handling.ipynb) |
# | Check if a file or folder exists | `Path(p).exists()` | [Paths with `pathlib`](../09%20-%20Files%20%26%20Data%20Formats/03%20-%20Paths%20with%20pathlib.ipynb) |
# | List the files of a folder | `Path(p).iterdir()`, `Path(p).glob("*.txt")` | [Paths with `pathlib`](../09%20-%20Files%20%26%20Data%20Formats/03%20-%20Paths%20with%20pathlib.ipynb) |
# | Create a folder (with its parents) | `Path(p).mkdir(parents=True, exist_ok=True)` | [Paths with `pathlib`](../09%20-%20Files%20%26%20Data%20Formats/03%20-%20Paths%20with%20pathlib.ipynb) |
# | Get the name or extension of a file | `path.name`, `path.stem`, `path.suffix` | [Paths with `pathlib`](../09%20-%20Files%20%26%20Data%20Formats/03%20-%20Paths%20with%20pathlib.ipynb) |
# | Join path parts | `Path("folder") / "file.txt"` | [Paths with `pathlib`](../09%20-%20Files%20%26%20Data%20Formats/03%20-%20Paths%20with%20pathlib.ipynb) |
# | Copy, move or delete files and folders | `shutil.copy`, `shutil.move`, `shutil.rmtree` | [`os`, `sys` & `shutil`](../09%20-%20Files%20%26%20Data%20Formats/04%20-%20os,%20sys%20%26%20shutil.ipynb) |
# | Read an environment variable | `os.getenv("NAME", "default")` | [`os`, `sys` & `shutil`](../09%20-%20Files%20%26%20Data%20Formats/04%20-%20os,%20sys%20%26%20shutil.ipynb) |
# | Save and load JSON | `json.dump(obj, file)`, `json.load(file)` | [JSON Files](../09%20-%20Files%20%26%20Data%20Formats/05%20-%20JSON%20Files.ipynb) |
# | Read and write CSV | `csv.reader(file)`, `csv.DictWriter(file, fieldnames)` | [CSV Files](../09%20-%20Files%20%26%20Data%20Formats/06%20-%20CSV%20Files.ipynb) |
# | Move around inside an open file | `file.seek(0)`, `file.tell()` | [Additional File Methods](../09%20-%20Files%20%26%20Data%20Formats/02%20-%20Additional%20File%20Methods.ipynb) |
#
# ## Dates and time
#
# | I want to... | Use | Where |
# |---|---|---|
# | Get the current date and time | `datetime.now()` | [`datetime` & `time`](../07%20-%20Standard%20Library%20Essentials/03%20-%20datetime%20%26%20time.ipynb) |
# | Turn a date into text | `dt.strftime("%Y-%m-%d")` | [`datetime` & `time`](../07%20-%20Standard%20Library%20Essentials/03%20-%20datetime%20%26%20time.ipynb) |
# | Turn text into a date | `datetime.strptime(text, "%Y-%m-%d")` | [`datetime` & `time`](../07%20-%20Standard%20Library%20Essentials/03%20-%20datetime%20%26%20time.ipynb) |
# | Add days to a date or find the difference | `dt + timedelta(days=7)`, `date2 - date1` | [`datetime` & `time`](../07%20-%20Standard%20Library%20Essentials/03%20-%20datetime%20%26%20time.ipynb) |
# | Pause the program | `time.sleep(seconds)` | [`datetime` & `time`](../07%20-%20Standard%20Library%20Essentials/03%20-%20datetime%20%26%20time.ipynb) |
#
# ## Classes
#
# | I want to... | Use | Where |
# |---|---|---|
# | Create a class with data | `class C:` with `__init__(self, ...)` | [Classes, Instances & `__init__`](../11%20-%20Object%20Oriented%20Programming/02%20-%20Classes,%20Instances%20%26%20__init__.ipynb) |
# | Reuse and extend another class | `class Child(Parent):`, `super().__init__(...)` | [Inheritance & `super()`](../11%20-%20Object%20Oriented%20Programming/06%20-%20Inheritance%20%26%20super.ipynb) |
# | Make a computed or read-only attribute | `@property` | [Encapsulation & Properties](../11%20-%20Object%20Oriented%20Programming/04%20-%20Encapsulation%20%26%20Properties.ipynb) |
# | Write a method that does not need the instance | `@staticmethod`, `@classmethod` | [Class Methods, Static Methods & Alternative Constructors](../11%20-%20Object%20Oriented%20Programming/05%20-%20Class%20%26%20Static%20Methods.ipynb) |
# | Generate `__init__` and `__repr__` automatically | `@dataclass` | [Dataclasses & Enums](../11%20-%20Object%20Oriented%20Programming/14%20-%20Dataclasses%20%26%20Enums.ipynb) |
# | Define a fixed set of named values | `class Color(Enum):` | [Dataclasses & Enums](../11%20-%20Object%20Oriented%20Programming/14%20-%20Dataclasses%20%26%20Enums.ipynb) |
# | Force subclasses to implement a method | `@abstractmethod` | [Abstract Base Classes (ABCs)](../11%20-%20Object%20Oriented%20Programming/10%20-%20Abstract%20Base%20Classes.ipynb) |
# | Control how an object prints | `__str__`, `__repr__` | [Dunder Methods & Operator Overloading](../11%20-%20Object%20Oriented%20Programming/11%20-%20Dunder%20Methods%20%26%20Operator%20Overloading.ipynb) |
# | Make objects work with `+`, `==`, `len()` | `__add__`, `__eq__`, `__len__` | [Dunder Methods & Operator Overloading](../11%20-%20Object%20Oriented%20Programming/11%20-%20Dunder%20Methods%20%26%20Operator%20Overloading.ipynb) |
# | Make my class usable with `with` | `__enter__` and `__exit__` | [Context Managers](../11%20-%20Object%20Oriented%20Programming/12%20-%20Context%20Managers.ipynb) |
# | Check the type of an object | `isinstance(obj, Class)` | [Inheritance & `super()`](../11%20-%20Object%20Oriented%20Programming/06%20-%20Inheritance%20%26%20super.ipynb) |
#
# ## Regular expressions
#
# | I want to... | Use | Where |
# |---|---|---|
# | Find the first match | `re.search(pattern, text)` | [Regex Functions, Match Objects & Replacement](../10%20-%20Regular%20Expressions/04%20-%20Regex%20Functions,%20Match%20Objects%20%26%20Replacement.ipynb) |
# | Find all matches | `re.findall(pattern, text)` | [Regex Functions, Match Objects & Replacement](../10%20-%20Regular%20Expressions/04%20-%20Regex%20Functions,%20Match%20Objects%20%26%20Replacement.ipynb) |
# | Replace by a pattern | `re.sub(pattern, repl, text)` | [Regex Functions, Match Objects & Replacement](../10%20-%20Regular%20Expressions/04%20-%20Regex%20Functions,%20Match%20Objects%20%26%20Replacement.ipynb) |
# | Split by a pattern | `re.split(pattern, text)` | [Regex Functions, Match Objects & Replacement](../10%20-%20Regular%20Expressions/04%20-%20Regex%20Functions,%20Match%20Objects%20%26%20Replacement.ipynb) |
# | Ignore case in a pattern | `re.IGNORECASE` | [Regex Flags, Performance & Best Practices](../10%20-%20Regular%20Expressions/05%20-%20Regex%20Flags,%20Performance%20%26%20Best%20Practices.ipynb) |
# | Capture parts of a match by name | `(?P<name>...)` | [Regex Groups, Alternation & Assertions](../10%20-%20Regular%20Expressions/03%20-%20Regex%20Groups,%20Alternation%20%26%20Assertions.ipynb) |
#
# ## Programs and projects
#
# | I want to... | Use | Where |
# |---|---|---|
# | Read command-line arguments | `argparse.ArgumentParser()`, `sys.argv` | [Command-Line Arguments](../13%20-%20Building%20Real%20Programs/02%20-%20Command-Line%20Arguments.ipynb) |
# | Run code only when the file is executed directly | `if __name__ == "__main__":` | [Packages & the `__main__` Guard](../13%20-%20Building%20Real%20Programs/01%20-%20Packages%20%26%20the%20__main__%20Guard.ipynb) |
# | Install a package | `pip install package_name` | [External Packages](../13%20-%20Building%20Real%20Programs/03%20-%20External%20Packages.ipynb) |
# | Create and activate a virtual environment | `python -m venv .venv` | [External Packages](../13%20-%20Building%20Real%20Programs/03%20-%20External%20Packages.ipynb) |
# | Test a function automatically | `unittest.TestCase` | [Unit Testing with `unittest`](../13%20-%20Building%20Real%20Programs/05%20-%20Unit%20Testing%20with%20unittest.ipynb) |
# | Test the examples in a docstring | `doctest` | [`doctest`](../13%20-%20Building%20Real%20Programs/06%20-%20doctest.ipynb) |
# | Follow the standard style rules | PEP 8: `snake_case`, 4 spaces, 79 characters | [Coding Style (PEP 8)](../04%20-%20Functions/13%20-%20Coding%20Style%20%28PEP%208%29.ipynb) |
# | Check if two names refer to the same object | `a is b` | [Operators](../01%20-%20Python%20Basics/04%20-%20Operators.ipynb) |
# | Combine conditions | `and`, `or`, `not` | [Operators](../01%20-%20Python%20Basics/04%20-%20Operators.ipynb) |
# | Work with the bits of an integer | `&`, `\|`, `^`, `~`, `<<`, `>>` | [Operators](../01%20-%20Python%20Basics/04%20-%20Operators.ipynb) |

# %%
# Try any of the tools from the table. Each line below checks one of them.
import copy, itertools, math, random, statistics
from collections import Counter

text = "  Hello, World  "
print(text.strip(), text.lower().strip(), text.split(","))
print(", ".join(["a", "b", "c"]), "banana".count("a"), "42".zfill(5))

items = [3, 1, 2, 3]
print(sorted(items), sorted(items, reverse=True), list(dict.fromkeys(items)))
print(Counter(items).most_common(1), max(items), sum(items))
print(list(itertools.pairwise(items)), list(itertools.accumulate(items)))

person = {"name": "Ann", "age": 30}
print(person.get("city", "unknown"), {**person, "city": "Cairo"})
print(sorted(person.items(), key=lambda pair: str(pair[1])))

nested = {"colors": ["red"]}
print(copy.deepcopy(nested) == nested, copy.copy(nested)["colors"] is nested["colors"])
print(round(3.14159, 2), math.floor(2.7), statistics.mean([1, 2, 3]))
